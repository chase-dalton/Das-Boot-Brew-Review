# %%
import pandas as pd

# %%
# read in the styles dataset
styles_df = pd.read_csv("../../Final_Project/beer-analytics/recipe_db/data/styles.csv", sep=";")
pd.set_option('display.max_columns', None)

styles_df.head(10)
# Out:
#     id parent_style_id                       name alt_names  \
# 0    1             NaN     Standard American Beer       NaN
# 1  01A               1       American Light Lager       NaN
# 2  01B               1             American Lager       NaN
# 3  01C               1                  Cream Ale       NaN
# 4  01D               1        American Wheat Beer       NaN
# 5    2             NaN        International Lager       NaN
# 6  02A               2   International Pale Lager       NaN
# 7  02B               2  International Amber Lager       NaN
# 8  02C               2   International Dark Lager       NaN
# 9    3             NaN                Czech Lager       NaN
#
#           alt_names_extra  abv_min  abv_max  ibu_min  ibu_max  srm_min  \
# 0                     NaN      NaN      NaN      NaN      NaN      NaN
# 1     American Lite Lager      2.8      4.2      8.0     12.0      2.0
# 2  Amerikanisches Pilsner      4.2      5.3      8.0     18.0      2.0
# ...

# %%
# read in the fermentables dataset
ferment_df = pd.read_csv("../../Final_Project/beer-analytics/recipe_db/data/fermentables.csv", sep=";")
pd.set_option('display.max_columns', None)

ferment_df.head(10)
# Out:
#                   name category  type  \
# 0    Basic Barley Malt    grain  base
# 1          Munich Malt    grain  base
# 2    Munich Light Malt    grain  base
# 3     Munich Dark Malt    grain  base
# 4          Vienna Malt    grain  base
# 5         Pilsner Malt    grain  base
# 6   Pilsner Light Malt    grain  base
# 7  Extra Pale Ale Malt    grain  base
# 8        Pale Ale Malt    grain  base
# 9        Mild Ale Malt    grain  base
#
#                                        alt_names  \
# 0  Brewers Malt 2-Row, Standard 2-Row, Base Malt
# 1                                            NaN
# 2                                  Munich Malt I
# 3                                 Munich Malt II
# 4                                            NaN
# 5                   Bohemian Pilsner, Lager Malt
# 6          Extra Light Pilsner, Light Lager Malt
# 7          Extra Pale Malt, Thomas Fawcett Pearl
# 8                                       ESB Malt
# ...

# %%
# read in the hops dataset
hops_df = pd.read_csv("../../Final_Project/beer-analytics/recipe_db/data/hops.csv", sep=";")
pd.set_option('display.max_columns', None)

hops_df.head(10)
# Out:
#             name           use origin  \
# 0        Admiral     bittering    GBR
# 1  African Queen  dual-purpose    ZAF
# 2          Agnus     bittering    CZH
# 3           Ahil         aroma    SLO
# 4        Ahtanum         aroma    USA
# 5          Akoya         aroma    GER
# 6       Alliance  dual-purpose    GBR
# 7          Aloha  dual-purpose    GER
# 8        Amallia  dual-purpose    USA
# 9       Amarillo         aroma    USA
#
#                                          substitutes  \
# 0                      Challenger, Northdown, Target
# 1           Amarillo, Cascade, Citra, Mosaic, Simcoe
# 2                   Columbus, Magnum, Nugget, Target
# 3                                                NaN
# 4          Amarillo, Cascade, Centennial, Willamette
# 5  Aurora, Hallertauer Tradition, Northern Brewer...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# ...

# %%
# read in the yeast dataset
yeast_df = pd.read_csv("../../Final_Project/beer-analytics/recipe_db/data/yeasts.csv", sep=";")
pd.set_option('display.max_columns', None)

yeast_df.head(10)
# Out:
#                 name alt_names alt_names_extra   lab alt_lab brand alt_brand  \
# 0           Fermoale       NaN             NaN   AEB     NaN   NaN       NaN
# 1       Fermoale AY3       NaN             NaN   AEB     NaN   NaN       NaN
# 2       Fermoale AY4       NaN             NaN   AEB     NaN   NaN       NaN
# 3       Fermolager W       NaN             NaN   AEB     NaN   NaN       NaN
# 4  Fermolager Berlin       NaN             NaN   AEB     NaN   NaN       NaN
# 5       Weiss Arome+       NaN             NaN   AEB     NaN   NaN       NaN
# 6       American Ale       NaN             NaN  Bio4   Bio 4   NaN       NaN
# 7    Heffeweizen Ale       NaN             NaN  Bio4   Bio 4   NaN       NaN
# 8         London ESB       NaN             NaN  Bio4   Bio 4   NaN       NaN
# 9   Norwegian Kveik        NaN             NaN  Bio4   Bio 4   NaN       NaN
#
#   product_id alt_product_id   type    form tolerance  tolerance_percent  \
# ...
