# %%
# import libraries
import psycopg2
import pandas as pd

# get username and password for DB
from config import sql_u
from config import sql_pw
from config import sql_host

# %%
# connect to DB
conn = psycopg2.connect(
    host=sql_host,
    port='5432',
    database='postgres',
    user=sql_u,
    password=sql_pw)

cur = conn.cursor()

# %%
# run query
sql_query = '''SELECT *
               FROM recipes;
            '''

cur.execute(sql_query)

# %%
# convert query results to DF
recipes_df = pd.DataFrame(cur.fetchall())
# add column names to DF
num_cols = len(cur.description)
col_names = [i[0] for i in cur.description]
recipes_df.columns = col_names
recipes_df.head()
# Out:
#    beerid                             name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  url  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 style  styleid size_l     og     fg   abv  \
# 0                           Cream Ale       45  21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85  20.82  1.083  1.021  8.16
# 2                        American IPA        7  18.93  1.063  1.018  5.91
# 3                        American IPA        7  22.71  1.061  1.017   5.8
# 4                   Belgian Blond Ale       20   50.0   1.06   1.01  6.48
#
#      ibu  ... boilgravity efficiency  mashthickness        sugarscale  \
# 0  17.65  ...       1.038       70.0            0.0  Specific Gravity
# 1  60.65  ...        1.07       70.0            0.0  Specific Gravity
# 2  59.25  ...         0.0       70.0            0.0  Specific Gravity
# 3  54.48  ...         0.0       70.0            0.0  Specific Gravity
# 4  17.84  ...        1.05       72.0            0.0  Specific Gravity
#
#   brewmethod pitchrate primarytemp primingmethod   primingamount   userid
# 0  All Grain       0.0       17.78    corn sugar          4.5 oz    116.0
# 1  All Grain       0.0         0.0             0               0    955.0
# 2    extract       0.0         0.0             0               0      0.0
# 3  All Grain       0.0         0.0             0               0      0.0
# 4  All Grain       0.0        19.0    Sukkerlake  6-7 g sukker/l  18325.0
#
# [5 rows x 23 columns]

# %%
# run query
sql_query = '''SELECT *
               FROM styles;
            '''

cur.execute(sql_query)

# convert query results to DF
styles_df = pd.DataFrame(cur.fetchall())
# add column names to DF
num_cols = len(cur.description)
col_names = [i[0] for i in cur.description]
styles_df.columns = col_names
styles_df.head()
# Out:
#                     style  styleid
# 0                 Altbier        1
# 1  Alternative Grain Beer        2
# 2  Alternative Sugar Beer        3
# 3      American Amber Ale        4
# 4     American Barleywine        5

# %%
# run query
sql_query = '''SELECT *
               FROM reviews;
            '''

cur.execute(sql_query)

# convert query results to DF
reviews_df = pd.DataFrame(cur.fetchall())
# add column names to DF
num_cols = len(cur.description)
col_names = [i[0] for i in cur.description]
reviews_df.columns = col_names
reviews_df.head()
# Out:
#    id                            brewery_name                 beer_style  \
# 0   0                 Närke Kulturbryggeri AB                    Old Ale
# 1   1          The Covey Restaurant & Brewery           Belgian Dark Ale
# 2   2                 Aviator Brewing Company               American IPA
# 3   3  Flossmoor Station Restaurant & Brewery    Belgian Strong Pale Ale
# 4   4                            Baltika-Baku  Dortmunder / Export Lager
#
#   brewery_id review_overall review_aroma review_appearance  \
# 0    10902.0            4.0          4.5               4.0
# 1    13338.0            4.0          4.0               4.0
# 2    18635.0            4.0          4.0               3.5
# 3      612.0            4.0          3.5              4.25
# 4    13640.0            3.0          3.0               3.0
#
#         review_palate review_taste beer_abv  beer_beerid  \
# 0                 4.0          4.5      8.2        57645
# 1                 4.0          4.4     10.0        49236
# 2                 4.0          4.0      6.6        50696
# 3                4.75          4.5      9.0        44353
# 4  3.1666666666666665          3.0      4.8        30080
#
#                        beer_name review_count
# 0                    ! (Old Ale)          1.0
# 1                            100          5.0
# 2                   100 Pale Ale          1.0
# 3  12  Belgian Golden Strong Ale          2.0
# 4                      33 Export          3.0

# %%
# close sql connection
cur.close()
conn.close()
